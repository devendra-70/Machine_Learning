# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("libraries imported")
# Out:
# libraries imported

# %%
#mean household income vs mean rent

# %%
path="test.csv"
data=pd.read_csv(path,index_col="UID")

# %%
data.head(10)
# Out:
#         BLOCKID  SUMLEVEL  COUNTYID  STATEID         state state_ab  \
# UID
# 255504      NaN       140       163       26      Michigan       MI
# 252676      NaN       140         1       23         Maine       ME
# 276314      NaN       140        15       42  Pennsylvania       PA
# 248614      NaN       140       231       21      Kentucky       KY
# 286865      NaN       140       355       48         Texas       TX
# 238666      NaN       140       131       12       Florida       FL
# 240174      NaN       140       187       13       Georgia       GA
# 266241      NaN       140         5       36      New York       NY
# 224873      NaN       140        29        6    California       CA
# 290904      NaN       140         7       53    Washington       WA
#
#                   city                  place     type primary  ...  \
# UID                                                             ...
# 255504         Detroit  Dearborn Heights City      CDP   tract  ...
# ...

# %%
sns.regplot(x=data["hi_mean"],y=data["rent_mean"])
plt.title="MEAN HOUSEHOLD INCOME vs MEAN RENT"

# %%
data1=pd.read.csv(path,index_col="UID")
sns.heatmap(data1,annot=True)
